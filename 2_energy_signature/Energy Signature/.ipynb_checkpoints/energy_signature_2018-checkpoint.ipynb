# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import statsmodels.api as sm
import plotly.express as px
import plotly.graph_objects as go
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D

# %%
df=pd.read_csv('my_data_2018.csv',sep=',',decimal=',',index_col=0)
# Out:
# Int64Index([1514765400, 1514766000, 1514766600, 1514767200, 1514767800,
#             1514768400, 1514769000, 1514769600, 1514770200, 1514770800,
#             ...
#             1546295400, 1546296000, 1546296600, 1546297200, 1546297800,
#             1546298400, 1546299000, 1546299600, 1546300200, 1546300800],
#            dtype='int64', name='Date_time', length=52560)

# %%
df.index=pd.to_datetime(df.index,unit='s')
# Out:
# DatetimeIndex(['2018-01-01 00:10:00', '2018-01-01 00:20:00',
#                '2018-01-01 00:30:00', '2018-01-01 00:40:00',
#                '2018-01-01 00:50:00', '2018-01-01 01:00:00',
#                '2018-01-01 01:10:00', '2018-01-01 01:20:00',
#                '2018-01-01 01:30:00', '2018-01-01 01:40:00',
#                ...
#                '2018-12-31 22:30:00', '2018-12-31 22:40:00',
#                '2018-12-31 22:50:00', '2018-12-31 23:00:00',
#                '2018-12-31 23:10:00', '2018-12-31 23:20:00',
#                '2018-12-31 23:30:00', '2018-12-31 23:40:00',
#                '2018-12-31 23:50:00', '2019-01-01 00:00:00'],
#               dtype='datetime64[ns]', name='Date_time', length=52560, freq=None)

# %%
df.columns
# Out:
# Index(['Heat', 'Cool', 'Elec', 'T_ex', 'T_in', 'Solar'], dtype='object')

# %%
df['deltaT']=df.T_in.astype(float)-df.T_ex.astype(float)
df['T_in']=df.T_in.astype(float)
df['T_ex']=df.T_ex.astype(float)
df['Heat']=df.Heat.astype(float)
df['Cool']=df.Cool.astype(float)
df['Solar']=df.Solar.astype(float)
df.head()
# Out:
#                          Heat  Cool               Elec      T_ex  T_in  Solar  \
# Date_time
# 2018-01-01 00:10:00  0.265106   0.0  46435.96817568001  2.296296  12.0    0.0
# 2018-01-01 00:20:00  0.270232   0.0  46435.96817568001  2.037037  12.0    0.0
# 2018-01-01 00:30:00  0.275377   0.0  46435.96817568001  1.777778  12.0    0.0
# 2018-01-01 00:40:00  0.280554   0.0  46435.96817568001  1.518519  12.0    0.0
# 2018-01-01 00:50:00  0.285784   0.0  46435.96817568001  1.259259  12.0    0.0
#
#                         deltaT
# Date_time
# 2018-01-01 00:10:00   9.703704
# 2018-01-01 00:20:00   9.962963
# 2018-01-01 00:30:00  10.222222
# 2018-01-01 00:40:00  10.481481
# 2018-01-01 00:50:00  10.740741

# %% [markdown]
# # 10 minutes

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()

# %%
# Fit the regression models
model_h = sm.OLS(heat_d.Heat,sm.add_constant(heat_d.deltaT))
model_c = sm.OLS(cool_d.Cool,sm.add_constant(cool_d.deltaT))

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
fig = plt.figure(figsize=(10,5))
plt.plot(heat_d.deltaT,results_h.predict(),'r', linewidth=1, label='Heating Regression Line')
plt.plot(cool_d.deltaT,results_c.predict(),'k', linewidth=1, label='Cooling Regression Line')
plt.scatter(heat_d.deltaT,heat_d.Heat, s=2, label='Observations')
plt.scatter(cool_d.deltaT,cool_d.Cool, s=2, color='r')
plt.xlabel('\u0394T [\u00B0C]')
plt.ylabel('Energy Consumption [kWh]')
plt.ylim(-0.01,1.5)
plt.legend()

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                 4.172e+04
# Date:                Tue, 19 Jan 2021   Prob (F-statistic):               0.00
# Time:                        18:34:47   Log-Likelihood:                 7200.2
# No. Observations:                8175   AIC:                        -1.440e+04
# Df Residuals:                    8173   BIC:                        -1.438e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6510      0.002    430.438      0.000       0.648       0.654
# deltaT        -0.0394      0.000   -204.267      0.000      -0.040      -0.039
# ==============================================================================
# Omnibus:                       77.480   Durbin-Watson:                   0.103
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.359
# Skew:                          -0.049   Prob(JB):                     9.90e-28
# Kurtosis:                       3.596   Cond. No.                         10.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.092
# Model:                            OLS   Adj. R-squared:                  0.092
# Method:                 Least Squares   F-statistic:                     1730.
# Date:                Tue, 19 Jan 2021   Prob (F-statistic):               0.00
# Time:                        18:35:00   Log-Likelihood:                -7670.8
# No. Observations:               17009   AIC:                         1.535e+04
# Df Residuals:                   17007   BIC:                         1.536e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1336      0.011    -12.167      0.000      -0.155      -0.112
# deltaT         0.0229      0.001     41.596      0.000       0.022       0.024
# ==============================================================================
# Omnibus:                     9836.520   Durbin-Watson:                   0.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94216.929
# Skew:                           2.670   Prob(JB):                         0.00
# Kurtosis:                      13.219   Cond. No.                         75.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Hourly

# %%
df=df.resample('H').mean()
df=df.dropna()

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()

# %%
# Fit the regression models
model_h = sm.OLS(heat_d.Heat,sm.add_constant(heat_d.deltaT))
model_c = sm.OLS(cool_d.Cool,sm.add_constant(cool_d.deltaT))

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
fig = plt.figure(figsize=(10,5))
plt.plot(heat_d.deltaT,results_h.predict(),'r', linewidth=1, label='Heating Regression Line')
plt.plot(cool_d.deltaT,results_c.predict(),'k', linewidth=1, label='Cooling Regression Line')
plt.scatter(heat_d.deltaT,heat_d.Heat, s=2, label='Observations')
plt.scatter(cool_d.deltaT,cool_d.Cool, s=2, color='r')
plt.xlabel('\u0394T [\u00B0C]')
plt.ylabel('Energy Consumption [kWh]')
plt.ylim(-0.01,1.27)
plt.legend()

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     1344.
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):          5.52e-208
# Time:                        12:44:34   Log-Likelihood:                 737.35
# No. Observations:                1431   AIC:                            -1471.
# Df Residuals:                    1429   BIC:                            -1460.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5771      0.008     70.842      0.000       0.561       0.593
# deltaT        -0.0330      0.001    -36.663      0.000      -0.035      -0.031
# ==============================================================================
# Omnibus:                      140.739   Durbin-Watson:                   0.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.181
# Skew:                          -0.733   Prob(JB):                     6.23e-46
# Kurtosis:                       4.159   Cond. No.                         19.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     203.1
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           1.25e-44
# Time:                        18:47:36   Log-Likelihood:                -1077.8
# No. Observations:                2960   AIC:                             2160.
# Df Residuals:                    2958   BIC:                             2172.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0886      0.026     -3.417      0.001      -0.139      -0.038
# deltaT         0.0194      0.001     14.253      0.000       0.017       0.022
# ==============================================================================
# Omnibus:                     1558.624   Durbin-Watson:                   0.483
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10703.639
# Skew:                           2.458   Prob(JB):                         0.00
# Kurtosis:                      10.913   Cond. No.                         77.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Dayly

# %%
df=df.resample('D').mean()
df=df.dropna()

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()

# %%
# Fit the regression models
model_h = sm.OLS(heat_d.Heat,sm.add_constant(heat_d.deltaT))
model_c = sm.OLS(cool_d.Cool,sm.add_constant(cool_d.deltaT))

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
fig = plt.figure(figsize=(10,5))
plt.plot(heat_d.deltaT,results_h.predict(),'r', linewidth=1, label='Heating Regression Line')
plt.plot(cool_d.deltaT,results_c.predict(),'k', linewidth=1, label='Cooling Regression Line')
plt.scatter(heat_d.deltaT,heat_d.Heat, s=10, label='Observations heating')
plt.scatter(cool_d.deltaT,cool_d.Cool, s=10, color='r',marker='*')
plt.xlabel('\u0394T [\u00B0C]')
plt.ylabel('Energy Consumption [kWh]')
plt.ylim(-0.01,0.8)
plt.legend(loc='upper left')

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     297.2
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           6.01e-35
# Time:                        18:47:37   Log-Likelihood:                 224.90
# No. Observations:                 128   AIC:                            -445.8
# Df Residuals:                     126   BIC:                            -440.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3137      0.010     30.118      0.000       0.293       0.334
# deltaT        -0.0184      0.001    -17.239      0.000      -0.021      -0.016
# ==============================================================================
# Omnibus:                       20.498   Durbin-Watson:                   1.410
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.893
# Skew:                          -0.912   Prob(JB):                     2.38e-06
# Kurtosis:                       4.236   Cond. No.                         27.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.227
# Method:                 Least Squares   F-statistic:                     62.39
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           1.61e-13
# Time:                        18:47:37   Log-Likelihood:                 122.09
# No. Observations:                 210   AIC:                            -240.2
# Df Residuals:                     208   BIC:                            -233.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1359      0.039     -3.524      0.001      -0.212      -0.060
# deltaT         0.0175      0.002      7.898      0.000       0.013       0.022
# ==============================================================================
# Omnibus:                       55.701   Durbin-Watson:                   1.498
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.988
# Skew:                           1.453   Prob(JB):                     6.43e-21
# Kurtosis:                       4.477   Cond. No.                         71.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Weekly

# %%
df=df.resample('W').mean()
df=df.dropna()

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()
heat_d.index
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-08', '2017-01-15', '2017-01-22',
#                '2017-01-29', '2017-02-05', '2017-02-12', '2017-02-19',
#                '2017-02-26', '2017-03-05', '2017-03-12', '2017-03-19',
#                '2017-03-26', '2017-04-02', '2017-04-09', '2017-04-16',
#                '2017-04-23', '2017-04-30', '2017-05-07', '2017-05-14',
#                '2017-05-21', '2017-09-24', '2017-10-01', '2017-10-08',
#                '2017-10-15', '2017-10-22', '2017-10-29', '2017-11-05',
#                '2017-11-12', '2017-11-19', '2017-11-26', '2017-12-03',
#                '2017-12-10', '2017-12-17', '2017-12-24', '2017-12-31',
#                '2018-01-07'],
#               dtype='datetime64[ns]', name='Date_time', freq=None)

# %%
heat_d.drop(heat_d.index[0], inplace=True)
heat_d.drop(heat_d.index[-1],inplace=True)

# %%
# Fit the regression models
model_h = sm.OLS(heat_d.Heat,sm.add_constant(heat_d.deltaT))
model_c = sm.OLS(cool_d.Cool,sm.add_constant(cool_d.deltaT))

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
fig = plt.figure(figsize=(10,5))
plt.plot(heat_d.deltaT,results_h.predict(),'r', linewidth=1, label='Heating Regression Line')
plt.plot(cool_d.deltaT,results_c.predict(),'k', linewidth=1, label='Cooling Regression Line')
plt.scatter(heat_d.deltaT,heat_d.Heat, s=10, label='Observations heating', marker='o')
plt.scatter(cool_d.deltaT,cool_d.Cool, s=30, color='r', marker='*',label='Observations cooling')
plt.xlabel('\u0394T [\u00B0C]')
plt.ylabel('Energy Consumption [kWh]')
plt.ylim(-0.01,0.4)
plt.legend(loc='upper left')

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     156.5
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):           5.24e-12
# Time:                        13:12:23   Log-Likelihood:                 67.193
# No. Observations:                  26   AIC:                            -130.4
# Df Residuals:                      24   BIC:                            -127.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2457      0.012     20.433      0.000       0.221       0.271
# deltaT        -0.0168      0.001    -12.512      0.000      -0.020      -0.014
# ==============================================================================
# Omnibus:                        0.579   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.749   Jarque-Bera (JB):                0.043
# Skew:                           0.055   Prob(JB):                        0.979
# Kurtosis:                       3.166   Cond. No.                         29.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     222.5
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):           3.17e-16
# Time:                        13:12:27   Log-Likelihood:                 72.583
# No. Observations:                  35   AIC:                            -141.2
# Df Residuals:                      33   BIC:                            -138.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2221      0.024     -9.070      0.000      -0.272      -0.172
# deltaT         0.0226      0.002     14.917      0.000       0.019       0.026
# ==============================================================================
# Omnibus:                       11.672   Durbin-Watson:                   2.270
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               11.165
# Skew:                          -1.159   Prob(JB):                      0.00376
# Kurtosis:                       4.511   Cond. No.                         75.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # By adding solar radiation as further regressor

# %% [markdown]
# # 10 minutes

# %%
df=pd.read_csv('my_data.csv',sep=',',decimal=',',index_col=0)

# %%
df.index=pd.to_datetime(df.index,unit='s')

# %%
df['deltaT']=df.T_in.astype(float)-df.T_ex.astype(float)
df['T_in']=df.T_in.astype(float)
df['T_ex']=df.T_ex.astype(float)
df['Heat']=df.Heat.astype(float)
df['Cool']=df.Cool.astype(float)
df['Solar']=df.Solar.astype(float)
df.head()
# Out:
#                          Heat  Cool               Elec      T_ex  T_in  Solar  \
# Date_time
# 2017-01-01 00:10:00  0.290765   0.0  46435.96817568001  0.723765  12.0    0.0
# 2017-01-01 00:20:00  0.285898   0.0  46435.96817568001  0.956790  12.0    0.0
# 2017-01-01 00:30:00  0.281058   0.0  46435.96817568001  1.189815  12.0    0.0
# 2017-01-01 00:40:00  0.276265   0.0  46435.96817568001  1.422840  12.0    0.0
# 2017-01-01 00:50:00  0.271526   0.0  46435.96817568001  1.655864  12.0    0.0
#
#                         deltaT
# Date_time
# 2017-01-01 00:10:00  11.276235
# 2017-01-01 00:20:00  11.043210
# 2017-01-01 00:30:00  10.810185
# 2017-01-01 00:40:00  10.577160
# 2017-01-01 00:50:00  10.344136

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()

# %%
# Fit the regression models
y_h = heat_d.Heat
y_c = cool_d.Cool
X_h = heat_d.loc[:, ['deltaT', 'Solar']]
X_c = cool_d.loc[:, ['deltaT', 'Solar']]
X_h = sm.add_constant(X_h)
X_c = sm.add_constant(X_c)

model_h = sm.OLS(y_h,X_h)
model_c = sm.OLS(y_c,X_c)

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
xx1c, xx2c = np.meshgrid(np.linspace(cool_d.deltaT.min(), cool_d.deltaT.max(), 100), 
                         np.linspace(cool_d.Solar.min(), cool_d.Solar.max(), 100))
Zc = results_c.params[0] + results_c.params[1] * xx1c + results_c.params[2] * xx2c

xx1h, xx2h = np.meshgrid(np.linspace(heat_d.deltaT.min(), heat_d.deltaT.max(), 100), 
                         np.linspace(heat_d.Solar.min(), heat_d.Solar.max(), 100))
Zh = results_h.params[0] + results_h.params[1] * xx1h + results_h.params[2] * xx2h


fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cool_d.deltaT, cool_d.Solar, cool_d.Cool, label='Observations Cooling')
ax.scatter(heat_d.deltaT, heat_d.Solar, heat_d.Heat, label='Observations Heating')
ax.plot_surface(xx1c, xx2c, Zc, color='r', alpha=0.8, linewidth=0)
ax.plot_surface(xx1h, xx2h, Zh, color='black', alpha=0.8, linewidth=0)

ax.set_xlabel('\u0394T [\u00B0C]')
ax.set_ylabel('Solar Radiation [W/m2]')
ax.set_zlabel('Energy Consumptions [kWh]]')
ax.set_title('Energy Consumption Regression using Solar Radiation (10 minutes resolution)')
ax.view_init(elev=0, azim=270)

scatter_cool = Line2D([0], [0], marker='o',color='white', label='Observations Cooling',
                      markerfacecolor='blue', markersize=15)
scatter_heat = Line2D([0], [0], marker='o',color='white', label='Observations Heating',
                      markerfacecolor='orange', markersize=15)
surf_cool = mpatches.Patch(color='red',label='Surface Cooling')
surf_heat = mpatches.Patch(color='black',label='Surface Heating')
ax.legend(handles=[scatter_cool,scatter_heat,surf_cool,surf_heat])

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.693
# Model:                            OLS   Adj. R-squared:                  0.693
# Method:                 Least Squares   F-statistic:                     8642.
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):               0.00
# Time:                        13:36:39   Log-Likelihood:                 6417.0
# No. Observations:                7658   AIC:                        -1.283e+04
# Df Residuals:                    7655   BIC:                        -1.281e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6545      0.003    214.825      0.000       0.649       0.660
# deltaT        -0.0376      0.000   -131.438      0.000      -0.038      -0.037
# Solar      -3.604e-05    1.3e-05     -2.779      0.005   -6.15e-05   -1.06e-05
# ==============================================================================
# Omnibus:                      169.487   Durbin-Watson:                   0.120
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              303.470
# Skew:                           0.175   Prob(JB):                     1.27e-66
# Kurtosis:                       3.911   Cond. No.                         400.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.087
# Model:                            OLS   Adj. R-squared:                  0.087
# Method:                 Least Squares   F-statistic:                     804.3
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):               0.00
# Time:                        13:36:41   Log-Likelihood:                -7045.5
# No. Observations:               16885   AIC:                         1.410e+04
# Df Residuals:                   16882   BIC:                         1.412e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0638      0.012     -5.522      0.000      -0.086      -0.041
# deltaT         0.0199      0.001     33.309      0.000       0.019       0.021
# Solar         -0.0014   7.02e-05    -20.452      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                    10168.755   Durbin-Watson:                   0.194
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           106441.778
# Skew:                           2.783   Prob(JB):                         0.00
# Kurtosis:                      13.969   Cond. No.                         179.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Hourly

# %%
df=df.resample('H').mean()
df=df.dropna()

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()

# %%
# Fit the regression models
y_h = heat_d.Heat
y_c = cool_d.Cool
X_h = heat_d.loc[:, ['deltaT', 'Solar']]
X_c = cool_d.loc[:, ['deltaT', 'Solar']]
X_h = sm.add_constant(X_h)
X_c = sm.add_constant(X_c)

model_h = sm.OLS(y_h,X_h)
model_c = sm.OLS(y_c,X_c)

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
xx1c, xx2c = np.meshgrid(np.linspace(cool_d.deltaT.min(), cool_d.deltaT.max(), 100), 
                         np.linspace(cool_d.Solar.min(), cool_d.Solar.max(), 100))
Zc = results_c.params[0] + results_c.params[1] * xx1c + results_c.params[2] * xx2c

xx1h, xx2h = np.meshgrid(np.linspace(heat_d.deltaT.min(), heat_d.deltaT.max(), 100), 
                         np.linspace(heat_d.Solar.min(), heat_d.Solar.max(), 100))
Zh = results_h.params[0] + results_h.params[1] * xx1h + results_h.params[2] * xx2h


fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cool_d.deltaT, cool_d.Solar, cool_d.Cool, label='Observations Cooling')
ax.scatter(heat_d.deltaT, heat_d.Solar, heat_d.Heat, label='Observations Heating')
ax.plot_surface(xx1c, xx2c, Zc, color='r', alpha=0.8, linewidth=0)
ax.plot_surface(xx1h, xx2h, Zh, color='black', alpha=0.8, linewidth=0)

ax.set_xlabel('\u0394T [\u00B0C]')
ax.set_ylabel('Solar Radiation [W/m2]')
ax.set_zlabel('Energy Consumptions [kWh]]')
ax.set_title('Energy Consumption Regression using Solar Radiation (Hourly resolution)')
ax.view_init(elev=0, azim=270)

scatter_cool = Line2D([0], [0], marker='o',color='white', label='Observations Cooling',
                      markerfacecolor='blue', markersize=15)
scatter_heat = Line2D([0], [0], marker='o',color='white', label='Observations Heating',
                      markerfacecolor='orange', markersize=15)
surf_cool = mpatches.Patch(color='red',label='Surface Cooling')
surf_heat = mpatches.Patch(color='black',label='Surface Heating')
ax.legend(handles=[scatter_cool,scatter_heat,surf_cool,surf_heat])

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.489
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     684.6
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):          3.27e-209
# Time:                        18:47:49   Log-Likelihood:                 744.01
# No. Observations:                1431   AIC:                            -1482.
# Df Residuals:                    1428   BIC:                            -1466.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5584      0.010     58.242      0.000       0.540       0.577
# deltaT        -0.0330      0.001    -36.802      0.000      -0.035      -0.031
# Solar          0.0002   4.19e-05      3.657      0.000     7.1e-05       0.000
# ==============================================================================
# Omnibus:                      132.312   Durbin-Watson:                   0.833
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              189.500
# Skew:                          -0.712   Prob(JB):                     7.09e-42
# Kurtosis:                       4.072   Cond. No.                         383.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.089
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     143.7
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           2.84e-60
# Time:                        18:47:49   Log-Likelihood:                -1038.9
# No. Observations:                2960   AIC:                             2084.
# Df Residuals:                    2957   BIC:                             2102.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0541      0.026     -2.089      0.037      -0.105      -0.003
# deltaT         0.0187      0.001     13.891      0.000       0.016       0.021
# Solar         -0.0014      0.000     -8.880      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                     1555.782   Durbin-Watson:                   0.484
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10783.295
# Skew:                           2.448   Prob(JB):                         0.00
# Kurtosis:                      10.966   Cond. No.                         182.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Dayly

# %%
df=df.resample('D').mean()
df=df.dropna()

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()

# %%
# Fit the regression models
y_h = heat_d.Heat
y_c = cool_d.Cool
X_h = heat_d.loc[:, ['deltaT', 'Solar']]
X_c = cool_d.loc[:, ['deltaT', 'Solar']]
X_h = sm.add_constant(X_h)
X_c = sm.add_constant(X_c)

model_h = sm.OLS(y_h,X_h)
model_c = sm.OLS(y_c,X_c)

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
xx1c, xx2c = np.meshgrid(np.linspace(cool_d.deltaT.min(), cool_d.deltaT.max(), 100), 
                         np.linspace(cool_d.Solar.min(), cool_d.Solar.max(), 100))
Zc = results_c.params[0] + results_c.params[1] * xx1c + results_c.params[2] * xx2c

xx1h, xx2h = np.meshgrid(np.linspace(heat_d.deltaT.min(), heat_d.deltaT.max(), 100), 
                         np.linspace(heat_d.Solar.min(), heat_d.Solar.max(), 100))
Zh = results_h.params[0] + results_h.params[1] * xx1h + results_h.params[2] * xx2h


fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cool_d.deltaT, cool_d.Solar, cool_d.Cool)
ax.scatter(heat_d.deltaT, heat_d.Solar, heat_d.Heat)
ax.plot_surface(xx1c, xx2c, Zc, color='r', alpha=0.8, linewidth=0)
ax.plot_surface(xx1h, xx2h, Zh, color='black', alpha=0.8, linewidth=0)

ax.set_xlabel('\u0394T [\u00B0C]')
ax.set_ylabel('Solar Radiation [W/m2]')
ax.set_zlabel('Energy Consumptions [kWh]]')
ax.set_title('Energy Consumption Regression using Solar Radiation (Dayly resolution)')
ax.view_init(elev=0, azim=270)

scatter_cool = Line2D([0], [0], marker='o',color='white', label='Observations Cooling',
                      markerfacecolor='blue', markersize=15)
scatter_heat = Line2D([0], [0], marker='o',color='white', label='Observations Heating',
                      markerfacecolor='orange', markersize=15)
surf_cool = mpatches.Patch(color='red',label='Surface Cooling')
surf_heat = mpatches.Patch(color='black',label='Surface Heating')
ax.legend(handles=[scatter_cool,scatter_heat,surf_cool,surf_heat])

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.758
# Model:                            OLS   Adj. R-squared:                  0.754
# Method:                 Least Squares   F-statistic:                     196.0
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           2.92e-39
# Time:                        18:47:52   Log-Likelihood:                 238.23
# No. Observations:                 128   AIC:                            -470.5
# Df Residuals:                     125   BIC:                            -461.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2699      0.012     21.677      0.000       0.245       0.295
# deltaT        -0.0169      0.001    -16.899      0.000      -0.019      -0.015
# Solar          0.0004   8.35e-05      5.378      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                       20.280   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.285
# Skew:                          -1.015   Prob(JB):                     5.33e-06
# Kurtosis:                       3.659   Cond. No.                         297.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.262
# Method:                 Least Squares   F-statistic:                     38.06
# Date:                Mon, 04 Jan 2021   Prob (F-statistic):           8.38e-15
# Time:                        18:47:52   Log-Likelihood:                 127.43
# No. Observations:                 210   AIC:                            -248.9
# Df Residuals:                     207   BIC:                            -238.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0721      0.042     -1.701      0.090      -0.156       0.011
# deltaT         0.0151      0.002      6.595      0.000       0.011       0.020
# Solar         -0.0013      0.000     -3.286      0.001      -0.002      -0.001
# ==============================================================================
# Omnibus:                       55.729   Durbin-Watson:                   1.617
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.735
# Skew:                           1.440   Prob(JB):                     4.42e-21
# Kurtosis:                       4.556   Cond. No.                         150.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # Weekly

# %%
df=df.resample('W').mean()
df=df.dropna()

# %%
# Extract the cooling and heating dataframes
cool_d = df.where(df['Cool']!=0.0).dropna()
heat_d = df.where(df['Heat']!=0.0).dropna()
heat_d.drop(heat_d.index[0], inplace=True)
heat_d.drop(heat_d.index[-1],inplace=True)

# %%
# Fit the regression models
y_h = heat_d.Heat
y_c = cool_d.Cool
X_h = heat_d.loc[:, ['deltaT', 'Solar']]
X_c = cool_d.loc[:, ['deltaT', 'Solar']]
X_h = sm.add_constant(X_h)
X_c = sm.add_constant(X_c)

model_h = sm.OLS(y_h,X_h)
model_c = sm.OLS(y_c,X_c)

# %%
results_h = model_h.fit()
results_c = model_c.fit()

# %%
# Plot the results
xx1c, xx2c = np.meshgrid(np.linspace(cool_d.deltaT.min(), cool_d.deltaT.max(), 100), 
                         np.linspace(cool_d.Solar.min(), cool_d.Solar.max(), 100))
Zc = results_c.params[0] + results_c.params[1] * xx1c + results_c.params[2] * xx2c

xx1h, xx2h = np.meshgrid(np.linspace(heat_d.deltaT.min(), heat_d.deltaT.max(), 100), 
                         np.linspace(heat_d.Solar.min(), heat_d.Solar.max(), 100))
Zh = results_h.params[0] + results_h.params[1] * xx1h + results_h.params[2] * xx2h


fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cool_d.deltaT, cool_d.Solar, cool_d.Cool, label='Observations Cooling')
ax.scatter(heat_d.deltaT, heat_d.Solar, heat_d.Heat, label='Observations Heating')
ax.plot_surface(xx1c, xx2c, Zc, color='r', alpha=0.8, linewidth=0)
ax.plot_surface(xx1h, xx2h, Zh, color='black', alpha=0.8, linewidth=0)

ax.set_xlabel('\u0394T [\u00B0C]')
ax.set_ylabel('Solar Radiation [W/m2]')
ax.set_zlabel('Energy Consumptions [kWh]]')
ax.set_title('Energy Consumption Regression using Solar Radiation (Weekly resolution)')
ax.view_init(elev=4, azim=270)

scatter_cool = Line2D([0], [0], marker='o',color='white', label='Observations Cooling',
                      markerfacecolor='blue', markersize=15)
scatter_heat = Line2D([0], [0], marker='o',color='white', label='Observations Heating',
                      markerfacecolor='orange', markersize=15)
surf_cool = mpatches.Patch(color='red',label='Surface Cooling')
surf_heat = mpatches.Patch(color='black',label='Surface Heating')
ax.legend(handles=[scatter_cool,scatter_heat,surf_cool,surf_heat])

# %%
results_c.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Cool   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     175.3
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):           1.19e-14
# Time:                        13:27:56   Log-Likelihood:                 77.200
# No. Observations:                  26   AIC:                            -148.4
# Df Residuals:                      23   BIC:                            -144.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1991      0.012     16.181      0.000       0.174       0.225
# deltaT        -0.0149      0.001    -14.945      0.000      -0.017      -0.013
# Solar          0.0005   8.94e-05      5.164      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        6.564   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.038   Jarque-Bera (JB):                4.562
# Skew:                          -0.911   Prob(JB):                        0.102
# Kurtosis:                       3.945   Cond. No.                         353.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
results_h.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Heat   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.905
# Method:                 Least Squares   F-statistic:                     162.6
# Date:                Fri, 15 Jan 2021   Prob (F-statistic):           1.72e-17
# Time:                        13:28:02   Log-Likelihood:                 78.984
# No. Observations:                  35   AIC:                            -152.0
# Df Residuals:                      32   BIC:                            -147.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1395      0.030     -4.618      0.000      -0.201      -0.078
# deltaT         0.0186      0.002     11.121      0.000       0.015       0.022
# Solar         -0.0008      0.000     -3.759      0.001      -0.001      -0.000
# ==============================================================================
# Omnibus:                        1.750   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.417   Jarque-Bera (JB):                0.799
# Skew:                           0.295   Prob(JB):                        0.671
# Kurtosis:                       3.447   Cond. No.                         245.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
